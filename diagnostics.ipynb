# %% [markdown]
# # Gathering Essential Diagnostic information
#
# ## Please run this next cell to gather some important data
#
# Please run the next cell; it should take a minute or so to run (mostly the network test).
# Rhen email me the output of the last cell to ed@edwarddonner.com.
# Alternatively: this will create a file called report.txt - just attach the file to your email.

# %%
# Run my diagnostics report to collect key information for debugging
# Please email me the results. Either copy & paste the output, or attach the file report.txt

# !pip install -q requests speedtest-cli psutil setuptools
from diagnostics import Diagnostics
Diagnostics().run()
# Out:
# Starting diagnostics at 2025-06-20 01:03:27
#
# ===== System Information =====
# Operating System: Darwin
# MacOS Version: 15.5
# Architecture: ('64bit', '')
# Machine: arm64
# Processor: arm
# Total RAM: 8.00 GB
# Available RAM: 3.12 GB
# Free Disk Space: 34.46 GB
#
# ===== File System Information =====
# Current Directory: /Users/imranpollob/Coding/llm_engineering
# Write permission: OK
#
# Files in Current Directory:
#  - .git
#  - .gitignore
#  - .ipynb_checkpoints
#  - LICENSE
#  - README.md
#  - SETUP-PC.md
#  - SETUP-PC.pdf
#  - SETUP-linux.md
#  - SETUP-linux.pdf
#  - SETUP-mac.md
#  - SETUP-mac.pdf
#  - __pycache__
#  - business.jpg
#  - community-contributions
#  - diagnostics.ipynb
#  - diagnostics.py
#  - environment.yml
#  - extras
#  - important.jpg
#  - report.txt
#  - requirements.txt
#  - resources.jpg
#  - thankyou.jpg
#  - voyage.jpg
#  - week1
#  - week2
#  - week3
#  - week4
#  - week5
#  - week6
#  - week7
#  - week8
#
# ===== Git Repository Information =====
# Git Repository Root: /Users/imranpollob/Coding/llm_engineering
# Current Commit: 3fb1c4d015b6815b40efbb958e8dda58df655daf
# Remote Origin: https://github.com/ed-donner/llm_engineering.git
#
# ===== Environment File Check =====
# WARNING: .env file not found in project root
#
# ===== Anaconda Environment Check =====
# Anaconda environment is active:
# Environment Path: /opt/anaconda3/envs/llms
# Environment Name: llms
# Conda Version: conda 24.9.2
#
# Python Environment:
# Python Version: 3.11.13 | packaged by conda-forge | (main, Jun  4 2025, 14:52:34) [Clang 18.1.8 ]
# Python Executable: /opt/anaconda3/envs/llms/bin/python
#
# Required Package Versions:
# openai: 1.88.0
# python-dotenv: 1.1.0
# requests: 2.32.4
# gradio: 5.34.2
# transformers: 4.52.4
#
# ===== Virtualenv Check =====
# No active virtualenv detected
#
# ===== Network Connectivity Check =====
# SSL Version: OpenSSL 3.5.0 8 Apr 2025
# ✓ Connected to https://www.google.com
#   Response time: 0.14s
#
# Performing bandwidth test using speedtest-cli...
# ERROR: Failed to retrieve speedtest configuration
#
# ===== Environment Variables Check =====
#
# PYTHONPATH is not set.
#
# Python sys.path:
#  - /opt/anaconda3/envs/llms/lib/python311.zip
#  - /opt/anaconda3/envs/llms/lib/python3.11
#  - /opt/anaconda3/envs/llms/lib/python3.11/lib-dynload
#  -
#  - /opt/anaconda3/envs/llms/lib/python3.11/site-packages
#  - /opt/anaconda3/envs/llms/lib/python3.11/site-packages/setuptools/_vendor
# WARNING: OPENAI_API_KEY environment variable is not set after calling load_dotenv()
#
# ===== Additional Diagnostics =====
# Temp directory is writable: /var/folders/62/348dpq8j74bcxmzddqr07vgm0000gn/T
#
# ===== Warnings Found =====
# The following warnings were detected. They might not prevent the program from running but could cause unexpected behavior:
# - .env file not found in project root
# - OPENAI_API_KEY environment variable is not set after calling load_dotenv()
#
# ===== Errors Found =====
# The following critical issues were detected. Please address them before proceeding:
# - Failed to retrieve speedtest configuration
#
#
# Completed diagnostics at 2025-06-20 01:03:27
#
#
# Please send these diagnostics to me at ed@edwarddonner.com
# Either copy & paste the above output into an email, or attach the file report.txt that has been created in this directory.
